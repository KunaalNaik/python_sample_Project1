# %%
import sqlalchemy
import pandas as pd
import xlsxwriter

# %%
view1_columns = pd.read_csv('input/view1_columns.csv')

# %%
view1_columns.head()
# Out:
#   table_name              column_name
# 0    studies                   nct_id
# 1    studies  last_update_posted_date
# 2    studies               start_date
# 3    studies          completion_date
# 4    studies  primary_completion_date

# %%
#pip install psycopg2

# %%
engine = sqlalchemy.create_engine("postgresql://devikasrinivas:Data1281@aact-db.ctti-clinicaltrials.org:5432/aact")

# %%
#pip install ipython-sql

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql $engine.url

# %% [markdown]
# # Task1

# %%
task1_dataframe = pd.read_sql ('SELECT * from studies LIMIT 3', engine)

# %%
task1_dataframe
# Out:
#         nct_id nlm_download_date_description study_first_submitted_date  \
# 0  NCT02695550                          None                 2016-02-23
# 1  NCT02695459                          None                 2016-02-18
# 2  NCT02695641                          None                 2016-02-25
#
#   results_first_submitted_date disposition_first_submitted_date  \
# 0                         None                             None
# 1                         None                             None
# 2                         None                             None
#
#   last_update_submitted_date study_first_submitted_qc_date  \
# 0                 2017-03-08                    2016-02-25
# 1                 2021-04-19                    2016-02-29
# 2                 2020-07-06                    2016-02-29
#
#   study_first_posted_date study_first_posted_date_type  \
# 0              2016-03-01                     Estimate
# 1              2016-03-01                     Estimate
# ...

# %% [markdown]
# # Task2

# %%
task2_dataframe = pd.read_sql ('SELECT * FROM countries, studies LIMIT 3', engine)

# %%
task2_dataframe
# Out:
#          id       nct_id           name  removed       nct_id  \
# 0  16680467  NCT00242736  United States    False  NCT02695550
# 1  16558062  NCT04562376         Sweden    False  NCT02695550
# 2  16680468  NCT00242749          Spain    False  NCT02695550
#
#   nlm_download_date_description study_first_submitted_date  \
# 0                          None                 2016-02-23
# 1                          None                 2016-02-23
# 2                          None                 2016-02-23
#
#   results_first_submitted_date disposition_first_submitted_date  \
# 0                         None                             None
# 1                         None                             None
# 2                         None                             None
#
#   last_update_submitted_date  ... plan_to_share_ipd  \
# 0                 2017-03-08  ...                No
# 1                 2017-03-08  ...                No
# 2                 2017-03-08  ...                No
#
# ...

# %%
task2_1_dataframe = pd.read_sql ('SELECT * FROM studies FULL OUTER JOIN countries ON studies.nct_id = countries.nct_id LIMIT 3', engine)

# %%
task2_1_dataframe
# Out:
#         nct_id nlm_download_date_description study_first_submitted_date  \
# 0  NCT00000102                          None                 1999-11-03
# 1  NCT00000104                          None                 1999-11-03
# 2  NCT00000105                          None                 1999-11-03
#
#   results_first_submitted_date disposition_first_submitted_date  \
# 0                         None                             None
# 1                         None                             None
# 2                         None                             None
#
#   last_update_submitted_date study_first_submitted_qc_date  \
# 0                 2005-06-23                    1999-11-03
# 1                 2005-06-23                    1999-11-03
# 2                 2017-11-27                    1999-11-03
#
#   study_first_posted_date study_first_posted_date_type  \
# 0              1999-11-04                     Estimate
# 1              1999-11-04                     Estimate
# ...

# %% [markdown]
# # Column Selections

# %%
studies_columns = view1_columns[view1_columns['table_name'] == 'studies']['column_name'].to_list()

# %%
view1_columns['column_name'].to_list()
# Out:
# ['nct_id',
#  'last_update_posted_date',
#  'start_date',
#  'completion_date',
#  'primary_completion_date',
#  'official_title',
#  'overall_status',
#  'phase',
#  'enrollment',
#  'number_of_arms',
#  'nct_id',
#  'mesh_term',
#  'nct_id',
#  'name',
#  'nct_id',
#  'measure',
#  'nct_id',
#  'allocation',
#  'masking_description',
#  'nct_id',
#  'sampling_method',
#  'healthy_volunteers',
#  'nct_id',
#  'country',
#  'nct_id',
#  'intervention_type',
#  'nct_id',
#  'title',
#  'nct_id',
#  'name']

# %%
task1_dataframe = task1_dataframe[studies_columns]

# %%
task3_dataframe = pd.read_sql ('SELECT * FROM browse_interventions LIMIT 3', engine)

# %%
browse_interventions_columns = view1_columns[view1_columns['table_name'] == 'browse_interventions']['column_name'].to_list()

# %%
task3_dataframe = task3_dataframe[browse_interventions_columns]

# %% [markdown]
# Importing to CSV

# %%
#submission = pd.DataFrame(task1_dataframe)

# %%
#submission.to_csv('Output/Task2.csv', header=True, index=False)

# %% [markdown]
# Importing to Excel

# %%
writer = pd.ExcelWriter('Output/Combined_file.xlsx', engine='xlsxwriter')
task1_dataframe.to_excel(writer, sheet_name='studies', index=False)
#task2_dataframe.to_excel(writer, sheet_name='studies+countries', index=False)
task3_dataframe.to_excel(writer, sheet_name='browse_interventions', index=False)
writer.save()
